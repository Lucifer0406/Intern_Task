# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# %%
df = pd.read_csv("GenderData.csv")
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
df_need = df[['long_hair','nose_long', 'lips_thin','distance_nose_to_lip_long','gender']]
df_need.head()
# Out:
#    long_hair  nose_long  lips_thin  distance_nose_to_lip_long  gender
# 0          1          0          1                          1    Male
# 1          0          0          1                          0  Female
# 2          0          1          1                          1    Male
# 3          0          1          1                          1    Male
# 4          1          0          0                          0  Female

# %%
plt.figure(figsize=(12,6))
parallel_coordinates(df_need,'gender',color=["blue","violet"])
plt.show()
